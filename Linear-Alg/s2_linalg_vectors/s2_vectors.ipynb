# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
v2 = [4, -2]
v3 = [4, -3, 2]
v3t = np.transpose(v3)

# 2D
plt.plot([0, v2[0]], [0, v2[1]])
plt.axis('equal')
plt.plot([-4, 4], [0, 0], 'k--')
plt.plot([0, 0], [-4, 4], 'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()

# %%
# 3D
fig = plt.figure(figsize=plt.figaspect(1))
ax = fig.gca(projection='3d')
ax.plot([0, v3[0]],[0, v3[1]],[0, v3[2]], linewidth=3)

# make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4],'k--')
ax.plot([0, 0],[-4, 4],[0, 0],'k--')
ax.plot([-4, 4],[0, 0],[0, 0],'k--')
plt.show()

# %%
# vector addition/subtraction
v1 = np.array([4, -1])
v2 = np.array([2, 4])
v3 = v1 + v2

# plot
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
plt.plot([0, v2[0]]+v1[0],[0, v2[1]]+v1[1],'r',label='v2')
plt.plot([0, v3[0]],[0, v3[1]],'k',label='v1+v2')

plt.legend()
plt.axis('square')
plt.axis((-6, 6, -6, 6 ))
plt.grid()
plt.show()

# %%
# scaling
v1 = np.array([3, -1])
l = 2.3
v1m = v1*l

# plot
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
plt.plot([0, v1m[0]],[0, v1m[1]],'r',label='\lambda v_1')

plt.axis('square')
axlim = max([max(abs(v1)),max(abs(v1m))])*1.5 # dynamic axis lim
plt.axis((-axlim,axlim,-axlim,axlim))
plt.grid()
plt.show()

# %%
# Vector dot product
v1 = np.array([ 1, 2, 3, 4, 5 ])
v2 = np.array([ 0, -4,  -3, 6, 5 ])

# method 1
dp1 = sum(np.multiply(v1,v2))

# method 2
dp2 = np.dot(v1, v2)

# method 3
dp3 = np.matmul(v1, v2)

# method 4
dp4 = 0

for i in range(len(v1)):
    dp4 = dp4 + v1[i]*v2[i]
    
print(dp1, dp2, dp3, dp4)
# Out:
# 32 32 32 32

# %%
## Distributive property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , (b+c) )
res2 = np.dot(a,b) + np.dot(a,c)

# compare them
print(a)
print([ res1,res2 ])
# Out:
# [-0.02057051 -1.49092639  0.93009023 -0.39885219  0.12468777  0.65373902
#  -0.35713083  0.95136876 -0.06139877 -0.58928352]
# [6.05313530476411, 6.05313530476411]

# %%
## Associative property

# create random vectors
n = 5
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a, np.dot(b,c))
res2 = np.dot( c, np.dot(a,b))

# compare them
# print(a, np.dot(b,c))
# print(c, np.dot(a,b))
print(res1)
print(res2)


### special cases where associative property works!
# 1) one vector is the zeros vector
# 2) a==b==c
# Out:
# [ 8.29460321 -1.50372876 10.68763206  0.55172652  2.76528891]
# [ 1.93844438  1.75071234 -1.8366359  -2.68664037  2.14488188]

# %%
# vector length
v1 = np.array([1, 2, 3, 4, 5, 6])

vl1 = np.sqrt(np.dot(v1, v1))

vl2 = np.linalg.norm(v1)

print(vl1, vl2)
# Out:
# 9.539392014169456 9.539392014169456

# %%
# The dot product from a geometric perspective
v1 = np.array([ 2,  4, -3 ])
v2 = np.array([ 0, -3, -3 ])

# compute the angle between two vectors
# 1 rad = 180°/π（about 57.29577951°）
ang = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)))
print(ang)

# 3D
fig = plt.figure(figsize=plt.figaspect(1))
ax = fig.gca(projection='3d')
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'b', linewidth=3)
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'r', linewidth=3)

# make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4],'k--')
ax.plot([0, 0],[-4, 4],[0, 0],'k--')
ax.plot([-4, 4],[0, 0],[0, 0],'k--')
plt.title('Angle between vectors: %s rad.' %ang)
plt.show()
# Out:
# 1.7024830348533126

# %%
## equivalence of algebraic and geometric dot product formulas
# two vectors
v1 = np.array([ 2,  4, -3 ])
v2 = np.array([ 0, -3, -3 ])

# algebraic
dp_a = np.dot( v1,v2 )

# geometric
dp_g = np.linalg.norm(v1)*np.linalg.norm(v2)*np.cos(ang)

print(dp_a, dp_g)
# Out:
# -3 -2.999999999999996

# %%
# Vector Hadamard multiplication - element-wise 
# create vectors
w1 = [ 1, 3, 5 ]
w2 = [ 3, 4, 2 ]

w3 = np.multiply(w1,w2)
print(w3)
# Out:
# [ 3 12 10]

# %%
# Vector outer product
v1 = np.array([  1, 2, 3 ])
v2 = np.array([ -1, 0, 1 ])

np.outer(v1, v2)
op = np.zeros((len(v1), len(v1)))

for i in range(0, len(v1)):
    for j in range(0, len(v2)):
        op[i,j] = v1[i] * v2[j]

print(op)
# Out:
# [[-1.  0.  1.]
#  [-2.  0.  2.]
#  [-3.  0.  3.]]

# %%
# Vector cross product
v1  = [ -3,  2, 5 ]
v2  = [  4, -3, 0 ]

v3a = np.cross(v1, v2)

v3b = [ [v1[1]*v2[2] - v1[2]*v2[1]],
        [v1[2]*v2[0] - v1[0]*v2[2]],
        [v1[0]*v2[1] - v1[1]*v2[0]] ]

print(v3a, v3b)

fig = plt.figure()
ax = fig.gca(projection = '3d')

# draw plane
xx, yy = np.meshgrid(np.linspace(-10,10,10), np.linspace(-10,10,10))
z1 = (-v3a[0]*xx - v3a[1]*yy)/v3a[2]
ax.plot_surface(xx,yy,z1, alpha=.2)

ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'k')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'k')
ax.plot([0, v3a[0]],[0, v3a[1]],[0, v3a[2]],'r')

ax.view_init(azim=150,elev=45)
plt.show()
# Out:
# [15 20  1] [[15], [20], [1]]

# %%
# conjugate transpose
# create a complex number
z = np.complex(3,4)

# magnitude
print( np.linalg.norm(z) )

# by transpose? (-7+24j)
print("z: ", z)
print("normal transpose: ", np.transpose(z))
print( np.transpose(z)*z )

# by Hermitian transpose - 25
print("Hermitian transpose", np.transpose(z.conjugate()))
print( np.transpose(z.conjugate())*z )

# complex vector
v = np.array( [ 3, 4j, 5+2j, np.complex(2,-5) ] )
print( v)
print( v.T )
print( np.transpose(v) )

print( np.transpose(v.conjugate()) )
# Out:
# 5.0
# z:  (3+4j)
# normal transpose:  (3+4j)
# (-7+24j)
# Hermitian transpose (3-4j)
# (25+0j)
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.-0.j 0.-4.j 5.-2.j 2.+5.j]

# %%
# unit vector
# vector
v1 = np.array([ -3, 6 ])

# mu
mu = 1/np.linalg.norm(v1)

v1n = v1*mu

# plot them
plt.plot([0, v1n[0]],[0, v1n[1]],'r',label='v1-norm',linewidth=5)
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')

# axis square
plt.axis('square')
plt.axis(( -6, 6, -6, 6 ))
plt.grid()
plt.legend()
plt.show()

# %%
# span
# set S
S1 = np.array([1, 1, 0])
S2 = np.array([1, 7, 0])

# vectors v and w
v = np.array([1, 2, 0])
w = np.array([3, 2, 1])

# draw vectors
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, S1[0]],[0, S1[1]],[.1, S1[2]+.1],'r',linewidth=3)
ax.plot([0, S2[0]],[0, S2[1]],[.1, S2[2]+.1],'r',linewidth=3)

ax.plot([0, v[0]],[0, v[1]],[.1, v[2]+.1],'g',linewidth=3)
ax.plot([0, w[0]],[0, w[1]],[0, w[2]],'b')

# now draw plane for S, S and v are in the same plane
xx, yy = np.meshgrid(range(-15,16), range(-15,16))
cp = np.cross(S1,S2)
z1 = (-cp[0]*xx - cp[1]*yy)*1./cp[2]
ax.plot_surface(xx,yy,z1)

plt.show()
